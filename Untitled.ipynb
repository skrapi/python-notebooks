# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.style.use('seaborn-pastel')


fig = plt.figure()
ax = plt.axes(xlim=(0, 4), ylim=(-2, 2))
line, = ax.plot([], [], lw=3)

def init():
    line.set_data([], [])
    return line,
def animate(i):
    x = np.linspace(0, 4, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

anim = FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)


anim.save('sine_wave.gif', writer='ffmpeg')
# Out:
# -------------------------------------------------------------------------
# OSError                                 Traceback (most recent call last)
# c:\users\sylva\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\animation.py in grab_frame(self, **savefig_kwargs)
#     375             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 376                              dpi=self.dpi, **savefig_kwargs)
#     377         except (RuntimeError, IOError) as e:
#
# c:\users\sylva\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#
# c:\users\sylva\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#
# c:\users\sylva\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\backends\backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     464                 cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 465             fh.write(renderer._renderer.buffer_rgba())
#     466     print_rgba = print_raw
#
# OSError: [Errno 22] Invalid argument
#
# During handling of the above exception, another exception occurred:
#
# OSError                                 Traceback (most recent call last)
# <ipython-input-4-af6218c05e98> in <module>()
#      22
#      23
# ---> 24 anim.save('sine_wave.gif', writer='ffmpeg')
#
# c:\users\sylva\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1172                         # TODO: See if turning off blit is really necessary
#    1173                         anim._draw_next_frame(d, blit=False)
# -> 1174                     writer.grab_frame(**savefig_kwargs)
#    1175
#    1176         # Reconnect signal for first draw if necessary
#
# c:\users\sylva\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\animation.py in grab_frame(self, **savefig_kwargs)
#     381                           'Stdout: {1} StdError: {2}. It may help to re-run '
#     382                           'with logging level set to '
# --> 383                           'DEBUG.'.format(e, out, err))
#     384
#     385     def _frame_sink(self):
#
# OSError: Error saving animation to file (cause: [Errno 22] Invalid argument) Stdout: b'' StdError: b''. It may help to re-run with logging level set to DEBUG.
